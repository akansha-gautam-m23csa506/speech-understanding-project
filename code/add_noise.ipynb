# %% [markdown]
# # Speech Understanding
# ## Robust Automatic Speech Recognition in Noisy Environment with Lip-Reading Assistance
# ### Akansha Gautam    (M23CSA506)
# ### Anchit Mulye      (M23CSA507)

# %% [markdown]
# # Import libraries

# %%
import os
import subprocess
import wget
import glob
import tarfile
import librosa
import soundfile as sf
import random
import numpy as np

# %% [markdown]
# # Add random noise to audio files

# %%
def audioread(path, norm = True, start=0, stop=None):
    path = os.path.abspath(path)
    if not os.path.exists(path):
        raise ValueError("[{}] does not exist!".format(path))
    try:
        x, sr = sf.read(path, start=start, stop=stop)
    except RuntimeError:
        print('WARNING: Audio type not supported')

    if len(x.shape) == 1:  # mono
        if norm:
            rms = (x ** 2).mean() ** 0.5
            if rms == 0:
               rms = 1
            scalar = 10 ** (-25 / 20) / (rms)
            x = x * scalar
        return x, sr
    else:
        x = x.T
        x = x.sum(axis=0)/x.shape[0]
        if norm:
            rms = (x ** 2).mean() ** 0.5
            if rms == 0:
               rms = 1
            scalar = 10 ** (-25 / 20) / (rms)
            x = x * scalar
        return x, sr

def audiowrite(data, fs, destpath, norm=False):
    if norm:
        eps = 0
        rms = (data ** 2).mean() ** 0.5
        scalar = 10 ** (-25 / 10) / (rms+eps)
        data = data * scalar
        if max(abs(data))>=1:
            data = data/max(abs(data), eps)

    destpath = os.path.abspath(destpath)
    destdir = os.path.dirname(destpath)

    if not os.path.exists(destdir):
        os.makedirs(destdir)

    sf.write(destpath, data, fs)
    return


def snr_mixer(clean, noise, snr):
    rmsclean = (clean ** 2).mean() ** 0.5
    if rmsclean == 0:
        rmsclean = 1

    scalarclean = 10 ** (-25 / 20) / rmsclean
    clean = clean * scalarclean
    rmsclean = (clean ** 2).mean() ** 0.5

    rmsnoise = (noise ** 2).mean() ** 0.5
    if rmsnoise == 0:
        rmsnoise = 1

    scalarnoise = 10 ** (-25 / 20) / rmsnoise
    noise = noise * scalarnoise
    rmsnoise = (noise ** 2).mean() ** 0.5
    if rmsnoise == 0:
        rmsnoise = 1

    noisescalar = np.sqrt(rmsclean / (10 ** (snr / 20)) / rmsnoise)
    noisenewlevel = noise * noisescalar
    noisyspeech = clean + noisenewlevel
    return clean, noisenewlevel, noisyspeech

def concatenate_noise_sample(noise, fs, len_clean):
    silence_length = 0.5
    while len(noise) <= len_clean:
       noiseconcat = np.append(noise, np.zeros(int(fs*silence_length)))
       noise = np.append(noiseconcat, noise)

    if noise.size > len_clean:
       noise = noise[0:len_clean]

    return noise

noisy_files = "noisy_files"
if not os.path.exists(noisy_files):
    os.makedirs(noisy_files)

SNR = 5

noise_sample_list = glob.glob('/Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/noise_samples/RIRS_NOISES/pointsource_noises/*_mono.wav', recursive=True)

clean_audio_list = [
    os.path.join(dp, f)
    for dp, dn, filenames in os.walk("/Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/train")
    for f in filenames
    if f.endswith('.wav') and not f.endswith('_noise.wav')
]

for clean_path in clean_audio_list:
    clean, fs = audioread(clean_path)
    file_name_clean = os.path.splitext(os.path.basename(clean_path))[0]
    clean_dir = os.path.dirname(clean_path)

    noise_path = random.choice(noise_sample_list)
    noise, n_fs = audioread(noise_path)

    if len(noise) > len(clean):
        noise = noise[:len(clean)]
    else:
        noise = concatenate_noise_sample(noise, fs, len(clean))

    _, _, noisy = snr_mixer(clean, noise, SNR)

    out_file_name = f"{file_name_clean}_{SNR}_noise.wav"
    out_path = os.path.join(clean_dir, out_file_name)
    audiowrite(noisy, fs, out_path, norm=False)

    print(f"Saved: {out_path}")
# Out:
# Saved: /Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/train/e5XSP8bktnc/e5XSP8bktnc_audio_5_noise.wav
# Saved: /Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/train/9Q21gUd6Dec/9Q21gUd6Dec_audio_5_noise.wav
# Saved: /Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/train/lTycj7X0nz4/lTycj7X0nz4_audio_5_noise.wav
# Saved: /Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/train/4dVUKpOJcEI/4dVUKpOJcEI_audio_5_noise.wav
# Saved: /Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/train/XFXcJ2tBlog/XFXcJ2tBlog_audio_5_noise.wav
# Saved: /Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/train/WKh6qtOQiEo/WKh6qtOQiEo_audio_5_noise.wav
# Saved: /Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/train/aMgpv8_kJuE/aMgpv8_kJuE_audio_5_noise.wav
# Saved: /Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/train/4dUJVqvs2Qo/4dUJVqvs2Qo_audio_5_noise.wav
# Saved: /Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/train/5JZDCfxcqT8/5JZDCfxcqT8_audio_5_noise.wav
# Saved: /Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/train/bNoDFfCAMoE/bNoDFfCAMoE_audio_5_noise.wav
# Saved: /Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/train/YXHQsV27oO0/YXHQsV27oO0_audio_5_noise.wav
# Saved: /Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/train/GtM2sM6r3So/GtM2sM6r3So_audio_5_noise.wav
# Saved: /Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/train/MZnQ3eZuUAE/MZnQ3eZuUAE_audio_5_noise.wav
# Saved: /Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/train/3fY4X9NlONY/3fY4X9NlONY_audio_5_noise.wav
# Saved: /Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/train/IrXrbrZWflA/IrXrbrZWflA_audio_5_noise.wav
# Saved: /Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/train/Cy9SUMj5wGY/Cy9SUMj5wGY_audio_5_noise.wav
# Saved: /Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/train/OE_1T44a_oI/OE_1T44a_oI_audio_5_noise.wav
# Saved: /Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/train/gXjw-trUtYg/gXjw-trUtYg_audio_5_noise.wav
# Saved: /Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/train/hkNEYLEOY14/hkNEYLEOY14_audio_5_noise.wav
# Saved: /Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/train/UNqnhQQM1Os/UNqnhQQM1Os_audio_5_noise.wav
# Saved: /Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/train/uoqk3TXOm5A/uoqk3TXOm5A_audio_5_noise.wav
# Saved: /Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/train/LAGyh7Lr9PU/LAGyh7Lr9PU_audio_5_noise.wav
# Saved: /Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/train/Kt0BgFt-h_4/Kt0BgFt-h_4_audio_5_noise.wav
# Saved: /Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/train/DIWf1t-HzwI/DIWf1t-HzwI_audio_5_noise.wav
# Saved: /Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/train/zjY8yp0Lea4/zjY8yp0Lea4_audio_5_noise.wav
# Saved: /Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/train/zJN5xeDHSmQ/zJN5xeDHSmQ_audio_5_noise.wav
# Saved: /Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/train/XJt3DGMLYas/XJt3DGMLYas_audio_5_noise.wav
# Saved: /Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/train/Nr5oAGQCcFg/Nr5oAGQCcFg_audio_5_noise.wav
# Saved: /Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/train/tpmDa6rRFbE/tpmDa6rRFbE_audio_5_noise.wav
# Saved: /Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/train/alHB2f34oRI/alHB2f34oRI_audio_5_noise.wav
# Saved: /Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/train/sujFCXbYkMo/sujFCXbYkMo_audio_5_noise.wav
# Saved: /Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/train/nJ9E-9vISVM/nJ9E-9vISVM_audio_5_noise.wav
# Saved: /Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/train/JpJoybtabbU/JpJoybtabbU_audio_5_noise.wav
# Saved: /Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/train/uUxK1OTWGa8/uUxK1OTWGa8_audio_5_noise.wav
# Saved: /Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/train/RdUVaYI3bmg/RdUVaYI3bmg_audio_5_noise.wav
# Saved: /Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/train/fWkbJs3XLrs/fWkbJs3XLrs_audio_5_noise.wav
# Saved: /Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/train/dvbTkFB6Lp8/dvbTkFB6Lp8_audio_5_noise.wav
# Saved: /Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/train/TfgG-f2kg6s/TfgG-f2kg6s_audio_5_noise.wav
# Saved: /Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/train/-A9gdf3j2xo/-A9gdf3j2xo_audio_5_noise.wav
# Saved: /Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/train/-bqS-Y5RtoI/-bqS-Y5RtoI_audio_5_noise.wav
# Saved: /Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/train/ksn7GP_hc34/ksn7GP_hc34_audio_5_noise.wav
# Saved: /Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/train/6aiBk4cZ5zI/6aiBk4cZ5zI_audio_5_noise.wav
# Saved: /Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/train/AojRKnEoNsQ/AojRKnEoNsQ_audio_5_noise.wav
# Saved: /Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/train/--ky4axzxbY/--ky4axzxbY_audio_5_noise.wav
# Saved: /Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/train/VaS8Uc0qQoE/VaS8Uc0qQoE_audio_5_noise.wav
# Saved: /Users/akanshagautam/Documents/MTech/Speech Understanding/Project/dataset/avspeech/train